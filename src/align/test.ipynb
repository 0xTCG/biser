# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_loghist(x, bins):
    hist, bins = np.histogram(x, bins=bins)
    logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
    plt.hist(x, bins=logbins)
    plt.xscale('log')
    plt.xlabel('Lengths')
    plt.ylabel('Count')


var = np.random.normal(0.5, 0.2, size=100)
mu = 80
sigma = 7
path = '/home/hiseric1/new_sedef/biser/src/results/l1' # 'results/hg19_5_2/elementaries_hg19.bed'

# dict - len, count
d = dict()
x = []
for i in open(path, 'r').readlines():
    line = i.split('\t')
    if len(line) > 5:
        len_ = min(int(line[2]) - int(line[1]) , int(line[5]) - int(line[4]))
        # len_ = max(int(line[17]) - int(line[16]), int(line[20]) - int(line[19]))
        x.append(len_)
        if len_ in d:
            d[len_] += 1
        else:
            d[len_] = 1
    

# plt.hist(x, 100)
# plt.hist(x, 20,
#          density=True,
#          histtype='bar',
#          facecolor='b',
#          alpha=0.5)
plot_loghist(x,100)

plt.show()

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt


labels, values = zip(*Counter(['A','B','A','C','A','A']).items())

indexes = np.arange(len(labels))
print (indexes)
print (labels)
print (values)

width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
plt.show()
# Out:
# [0 1 2]
# ('A', 'B', 'C')
# (4, 1, 1)
